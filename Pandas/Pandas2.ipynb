# %% [markdown]
# # Welcome To Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## What is Dataframe ?
#
# Pandas DataFrame is a way to represent and work with tabular data. It can be seen as a table that organizes data into rows and columns, making it a two-dimensional data structure.
#
# A single row or column in dataframe is called a series.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Creating DataFrame

# %%
# using list

student_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]

student_data = pd.DataFrame(student_data,columns=['iq','marks','package'])

# %%
# using dict

student_dict = {
    'name' : ['uc','ac','vk','sh'],
    'iq' : [100,90,120,80],
    'marks' : [80,70,100,50],
    'package' : [10,7,14,2]
}

student_dict = pd.DataFrame(student_dict)
student_dict.set_index('name',inplace=True)

# %% [markdown]
# ### Using read functions

# %%
#using read_csv()

movies = pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-pandas2/movies.csv')
ipl = pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-pandas2/ipl-matches.csv')

# %%
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %% [markdown]
# ### DataFrame Attributes and Methods

# %%
# shape
movies.shape
# Out:
# (1629, 18)

# %%
# dtypes

movies.dtypes

# Caution! - .dtype and .dtypes both exist, for dataframe we use .dtypes
# Out:
# title_x                 str
# imdb_id                 str
# poster_path             str
# wiki_link               str
# title_y                 str
# original_title          str
# is_adult              int64
# year_of_release       int64
# runtime                 str
# genres                  str
# imdb_rating         float64
# imdb_votes            int64
# story                   str
# summary                 str
# tagline                 str
# actors                  str
# wins_nominations        str
# release_date            str
# dtype: object

# %%
# index

movies.index
# Out:
# RangeIndex(start=0, stop=1629, step=1)

# %%
# columns 

movies.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='str')

# %%
# values -> output is a numpy array

student_data.values
# Out:
# array([[100,  80,  10],
#        [ 90,  70,   7],
#        [120, 100,  14],
#        [ 80,  50,   2]])

# %%
# head()

movies.head(2) #default value is 5
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
# tail()

movies.tail(3) #default 5
# Out:
#               title_x     imdb_id  \
# 1626  Sabse Bada Sukh   tt0069204
# 1627            Daaka  tt10833860
# 1628         Humsafar   tt2403201
#
#                                             poster_path  \
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link          title_y  \
# 1626  https://en.wikipedia.org/wiki/Sabse_Bada_Sukh  Sabse Bada Sukh
# 1627            https://en.wikipedia.org/wiki/Daaka            Daaka
# 1628         https://en.wikipedia.org/wiki/Humsafar         Humsafar
#
#        original_title  is_adult  year_of_release runtime         genres  \
# 1626  Sabse Bada Sukh         0             2018      \N   Comedy|Drama
# 1627            Daaka         0             2019     136         Action
# 1628         Humsafar         0             2011      35  Drama|Romance
#
# ...

# %%
# sample() - use if data is biased
 
ipl.sample(3) #default 1
# Out:
#           ID       City        Date   Season MatchNumber  \
# 177  1216538        NaN  2020-10-04  2020/21          17
# 286  1136589  Bengaluru  2018-04-29     2018          29
# 788   419152     Mumbai  2010-04-13  2009/10          47
#
#                            Team1                  Team2  \
# 177               Mumbai Indians    Sunrisers Hyderabad
# 286  Royal Challengers Bangalore  Kolkata Knight Riders
# 788               Mumbai Indians       Delhi Daredevils
#
#                        Venue             TossWinner TossDecision SuperOver  \
# 177  Sharjah Cricket Stadium         Mumbai Indians          bat         N
# 286    M.Chinnaswamy Stadium  Kolkata Knight Riders        field         N
# 788        Brabourne Stadium         Mumbai Indians          bat         N
#
#                WinningTeam    WonBy  Margin method Player_of_Match  \
# 177         Mumbai Indians     Runs    34.0    NaN        TA Boult
# ...

# %%
#info - A very high level summary(information) about the data frame.

movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   str
#  1   imdb_id           1629 non-null   str
#  2   poster_path       1526 non-null   str
#  3   wiki_link         1629 non-null   str
#  4   title_y           1629 non-null   str
#  5   original_title    1629 non-null   str
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   str
#  9   genres            1629 non-null   str
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   str
#  13  summary           1629 non-null   str
#  14  tagline           557 non-null    str
#  15  actors            1624 non-null   str
#  16  wins_nominations  707 non-null    str
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
# describe() - A statistical summary.
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
# describe() - A statistical summary.

movies.describe().T #transpose for a better view.
# Out:
#                   count         mean           std     min     25%     50%  \
# is_adult         1629.0     0.000000      0.000000     0.0     0.0     0.0
# year_of_release  1629.0  2010.263966      5.381542  2001.0  2005.0  2011.0
# imdb_rating      1629.0     5.557459      1.567609     0.0     4.4     5.6
# imdb_votes       1629.0  5384.263352  14552.103231     0.0   233.0  1000.0
#
#                     75%       max
# is_adult            0.0       0.0
# year_of_release  2015.0    2019.0
# imdb_rating         6.8       9.4
# imdb_votes       4287.0  310481.0

# %%
# isnull() - Boolean array of missing values.
ipl.isnull().sum() # number of missing value in each column.
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
ipl.isnull().sum().sum() #Count of all missing values.
# Out:
# np.int64(1012)

# %%
# isnull() - To find out the total percent of missing values in the data.

ipl.isnull().mean().mean() * 100
# Out:
# np.float64(5.326315789473683)

# %%
# duplicated()

movies.duplicated().sum() # Total duplicate values. Can find percentage like about aswell.
# Out:
# np.int64(0)

# %%
student_data
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# rename() - Rename column names in the dataframe.

student_data.rename(columns={'marks' : 'percentage'}) #not inplace
# student_data.rename(columns={'marks' : 'percentage'},inplace=1inplace) #
# Out:
#     iq  percentage  package
# 0  100          80       10
# 1   90          70        7
# 2  120         100       14
# 3   80          50        2

# %% [markdown]
# ## Mathematical Functions
#
# (Similar to Series)
#
# - By default applies on columns (axis = 0), can also be performed on rows (axis = 1)

# %%
student_data
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# sum
student_data.sum()
# Out:
# iq         390
# marks      300
# package     33
# dtype: int64

# %%
# sum
student_data.sum(axis = 1) #row-wise sum
# Out:
# 0    190
# 1    167
# 2    234
# 3    132
# dtype: int64

# %%
# prod
student_data.prod()
# Out:
# iq         86400000
# marks      28000000
# package        1960
# dtype: int64

# %%
# min and and max
print(student_data.min(),'\n')
print(student_data.max())
# Out:
# iq         80
# marks      50
# package     2
# dtype: int64
#
# iq         120
# marks      100
# package     14
# dtype: int64

# %%
# mean, median, mode, std, var
print(student_data.mean(),'\n')
print(student_data.median(),'\n')
print(student_data.mode(),'\n')
print(student_data.std(),'\n')
print(student_data.var(),'\n')
# Out:
# iq         97.50
# marks      75.00
# package     8.25
# dtype: float64
#
# iq         95.0
# marks      75.0
# package     8.5
# dtype: float64
#
#     iq  marks  package
# 0   80     50        2
# 1   90     70        7
# 2  100     80       10
# 3  120    100       14
#
# iq         17.078251
# marks      20.816660
# package     5.057997
# dtype: float64
#
# iq         291.666667
# marks      433.333333
# package     25.583333
# dtype: float64

# %% [markdown]
# ## Selecting columns from a Dataframe

# %%
# single column -> output is a series
movies['genres']
# Out:
# 0       Action|Drama|War
# 1                    War
# 2        Biography|Drama
# 3            Crime|Drama
# 4                  Drama
#               ...
# 1624               Drama
# 1625               Drama
# 1626        Comedy|Drama
# 1627              Action
# 1628       Drama|Romance
# Name: genres, Length: 1629, dtype: str

# %%
type(movies['genres']) # output is a series
# Out:
# pandas.Series

# %%
# multiple columns (like fancy indexing)

movies[['title_x','year_of_release','actors']] 

#pass multiple column names as a single list
# Out:
#                                    title_x  year_of_release  \
# 0                 Uri: The Surgical Strike             2019
# 1                            Battalion 609             2019
# 2     The Accidental Prime Minister (film)             2019
# 3                          Why Cheat India             2019
# 4                          Evening Shadows             2018
# ...                                    ...              ...
# 1624                 Tera Mera Saath Rahen             2001
# 1625                  Yeh Zindagi Ka Safar             2001
# 1626                       Sabse Bada Sukh             2018
# 1627                                 Daaka             2019
# 1628                              Humsafar             2011
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# ...

# %%
type(movies[['title_x','year_of_release','actors']]) #this is a df.
# Out:
# pandas.DataFrame

# %% [markdown]
# ## Selecting Rows
#
# - iloc: searches using index positions
# - loc: searches using index labels

# %%
# single row

movies.iloc[5]
# Out:
# title_x                                                   Soni (film)
# imdb_id                                                     tt6078866
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                   https://en.wikipedia.org/wiki/Soni_(film)
# title_y                                                          Soni
# original_title                                                   Soni
# is_adult                                                            0
# year_of_release                                                  2018
# runtime                                                            97
# genres                                                          Drama
# imdb_rating                                                       7.2
# imdb_votes                                                       1595
# story               Soni  a young policewoman in Delhi  and her su...
# ...

# %%
type(movies.iloc[0])
# Out:
# pandas.Series

# %%
# multiple rows

movies.iloc[10:15,[1,2,4]] # we can also specify which columns to select with this extra argument ,[1,2,4]
# Out:
#       imdb_id                                        poster_path  \
# 10  tt8396186  https://upload.wikimedia.org/wikipedia/en/thum...
# 11  tt2395469  https://upload.wikimedia.org/wikipedia/en/thum...
# 12  tt9319812  https://upload.wikimedia.org/wikipedia/en/thum...
# 13  tt7639372  https://upload.wikimedia.org/wikipedia/en/thum...
# 14  tt8108200  https://upload.wikimedia.org/wikipedia/en/thum...
#
#           title_y
# 10         Amavas
# 11      Gully Boy
# 12      Hum chaar
# 13  Total Dhamaal
# 14     Sonchiriya

# %%
type(movies.iloc[1:5])
# Out:
# pandas.DataFrame

# %%
movies.iloc[5:15:2] #using stride
# works like python slicing
# Out:
#              title_x    imdb_id  \
# 5        Soni (film)  tt6078866
# 7         Bombairiya  tt4971258
# 9   Thackeray (film)  tt7777196
# 11         Gully Boy  tt2395469
# 13     Total Dhamaal  tt7639372
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 13  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                          wiki_link        title_y  \
# 5        https://en.wikipedia.org/wiki/Soni_(film)           Soni
# 7         https://en.wikipedia.org/wiki/Bombairiya     Bombairiya
# 9   https://en.wikipedia.org/wiki/Thackeray_(film)      Thackeray
# 11         https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 13     https://en.wikipedia.org/wiki/Total_Dhamaal  Total Dhamaal
#
# ...

# %%
# fancy indexing
movies.iloc[[0,7,10]]
# Out:
#                      title_x    imdb_id  \
# 0   Uri: The Surgical Strike  tt8291224
# 7                 Bombairiya  tt4971258
# 10                    Amavas  tt8396186
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 0   https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 7            https://en.wikipedia.org/wiki/Bombairiya
# 10               https://en.wikipedia.org/wiki/Amavas
#
#                      title_y            original_title  is_adult  \
# 0   Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 7                 Bombairiya                Bombairiya         0
# 10                    Amavas                    Amavas         0
#
#     year_of_release runtime              genres  imdb_rating  imdb_votes  \
# ...

# %%
student_dict
# Out:
#        iq  marks  package
# name
# uc    100     80       10
# ac     90     70        7
# vk    120    100       14
# sh     80     50        2

# %%
# loc
student_dict.loc['uc']
# Out:
# iq         100
# marks       80
# package     10
# Name: uc, dtype: int64

# %%
student_dict.loc['uc':'vk'] # both end values are inclusive
# Out:
#        iq  marks  package
# name
# uc    100     80       10
# ac     90     70        7
# vk    120    100       14

# %%
student_dict.loc['uc':'vk'] # both end values are inclusive
# Out:
#        iq  marks  package
# name
# uc    100     80       10
# ac     90     70        7
# vk    120    100       14

# %%
# using fancy indexing
student_dict.loc[['uc','vk','ac']]
# Out:
#        iq  marks  package
# name
# uc    100     80       10
# vk    120    100       14
# ac     90     70        7

# %%
# using iloc on custom index is possible, cause there is still internal indexing.
student_dict.iloc[1:3] # all iloc variations will work including fancy indexing.
# Out:
#        iq  marks  package
# name
# ac     90     70        7
# vk    120    100       14

# %% [markdown]
# ## Selecting both rows and columns

# %%
# Select first 3 columns of first 3 movies.

movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,"title_x":'poster_path']
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# ## Filtering a Dataframe

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# find all the final winners

ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over finishes have occured

(ipl[ipl['SuperOver'] == 'Y']).shape[0]
# Out:
# 14

# %%
# how many matches has csk won in kolkata

ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# is toss winner, the match winner

ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0]/ipl.shape[0] * 100
# Out:
# 51.473684210526315

# %%
# Better way

(ipl['TossWinner'] == ipl['WinningTeam']).mean() * 100
# Out:
# np.float64(51.473684210526315)

# %%
movies.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
# Movies with rating higher than 8 and votes > 10000

movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# Action movies with rating higher than 7.5

movies[(movies['imdb_rating'] > 7.5) & (movies['genres'] == ('Action' in movies['genres']))].shape[0]
# Out:
# 0

# %% [markdown]
# ## Adding new Columns to dataframe

# %%
# lets add a new column named country
movies['Country'] = 'India'
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# Using exisitng column to create a new column

# make a new column named lead actor, and it will be the first name from actors
movies.dropna(inplace=True)
movies['Lead Actor'] = movies['actors'].str.split('|').apply(lambda x:x[0]) #error if there is a missing value

# %%
movies.head(1)
# Out:
#       title_x    imdb_id                                        poster_path  \
# 11  Gully Boy  tt2395469  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                   wiki_link    title_y original_title  \
# 11  https://en.wikipedia.org/wiki/Gully_Boy  Gully Boy      Gully Boy
#
#     is_adult  year_of_release runtime       genres  imdb_rating  imdb_votes  \
# 11         0             2019     153  Drama|Music          8.2       22440
#
#                                                 story  \
# 11  Gully Boy is a film about a 22-year-old boy "M...
#
#                                               summary            tagline  \
# 11  A coming-of-age story based on the lives of st...  Apna Time Aayega!
#
#                                                actors        wins_nominations  \
# 11  Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...  6 wins & 3 nominations
#
#               release_date Country     Lead Actor
# ...

# %% [markdown]
# ## Important Dataframe Functions

# %% [markdown]
# ### .info()

# %%
# astype - changes datatype of a given column

ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
ipl['ID'] = ipl['ID'].astype('uint16')

# %%
ipl.sample()
# Out:
#         ID       City        Date Season MatchNumber  \
# 514  13109  Bangalore  2014-05-13   2014          38
#
#                            Team1             Team2                  Venue  \
# 514  Royal Challengers Bangalore  Delhi Daredevils  M Chinnaswamy Stadium
#
#            TossWinner TossDecision SuperOver                  WinningTeam  \
# 514  Delhi Daredevils        field         N  Royal Challengers Bangalore
#
#     WonBy  Margin method Player_of_Match  \
# 514  Runs    16.0    NaN    Yuvraj Singh
#
#                                           Team1Players  \
# 514  ['CH Gayle', 'PA Patel', 'V Kohli', 'AB de Vil...
#
#                                           Team2Players    Umpire1    Umpire2
# 514  ['Q de Kock', 'M Vijay', 'MA Agarwal', 'KP Pie...  K Srinath  RJ Tucker

# %%
ipl.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    uint16
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    str
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    str
#  6   Team2            950 non-null    str
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
#  17  Team2Players     950 non-null    str
# ...

# %%
ipl['Season'] = ipl['Season'].astype('category')
ipl['Team1'] = ipl['Team1'].astype('category')
ipl['Team2'] = ipl['Team2'].astype('category')

# %%
ipl.info() # we reduced almost 20% percent of memory footprint
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    uint16
#  1   City             899 non-null    str
#  2   Date             950 non-null    str
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    str
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    str
#  8   TossWinner       950 non-null    str
#  9   TossDecision     950 non-null    str
#  10  SuperOver        946 non-null    str
#  11  WinningTeam      946 non-null    str
#  12  WonBy            950 non-null    str
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     str
#  15  Player_of_Match  946 non-null    str
#  16  Team1Players     950 non-null    str
# ...

# %%
student_data
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %% [markdown]
# ### .value_counts()

# %%
# value_counts (applicable on both series and df)
print(student_data.value_counts()) # frequency count of rows

# it is more useful on series datatype
# Out:
# iq   marks  package
# 100  80     10         1
# 90   70     7          1
# 120  100    14         1
# 80   50     2          1
# Name: count, dtype: int64

# %%
ipl.sample()
# Out:
#         ID    City        Date Season MatchNumber          Team1  \
# 324  34064  Kanpur  2017-05-10   2017          50  Gujarat Lions
#
#                 Team2       Venue        TossWinner TossDecision SuperOver  \
# 324  Delhi Daredevils  Green Park  Delhi Daredevils        field         N
#
#           WinningTeam    WonBy  Margin method Player_of_Match  \
# 324  Delhi Daredevils  Wickets     2.0    NaN         SS Iyer
#
#                                           Team1Players  \
# 324  ['DR Smith', 'Ishan Kishan', 'SK Raina', 'KD K...
#
#                                           Team2Players   Umpire1       Umpire2
# 324  ['SV Samson', 'KK Nair', 'RR Pant', 'SS Iyer',...  YC Barde  AK Chaudhary

# %%
# example value counts -> player who has won most potm in finals and qualifiers

ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# KA Pollard           3
# SK Raina             3
# JJ Bumrah            2
# SR Watson            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# YK Pathan            2
# A Kumble             2
# HH Pandya            1
# JC Buttler           1
# RM Patidar           1
# DA Miller            1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# TA Boult             1
# MP Stoinis           1
# KS Williamson        1
# RR Pant              1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# KH Pandya            1
# KV Sharma            1
# NM Coulter-Nile      1
# Washington Sundar    1
# BCJ Cutting          1
# DA Warner            1
# MC Henriques         1
# RG Sharma            1
# A Nehra              1
# V Sehwag             1
# UT Yadav             1
# Harbhajan Singh      1
# BJ Hodge             1
# MEK Hussey           1
# MS Bisla             1
# ...

# %%
# Toss decision plot
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: >

# %%
# how many matches each team has played

(ipl['Team1'].value_counts()) + (ipl['Team2'].value_counts())
# Out:
# Team1
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %% [markdown]
# ### .sort_values()

# %%
# sort_values() (series and df) -> ascending -> na_position -> inplace -> multiple columns

# %%
x = pd.Series([19,41,56,2,5,3,636,2626,1,3,5]).sort_values()
x
# Out:
# 8        1
# 3        2
# 5        3
# 9        3
# 4        5
# 10       5
# 0       19
# 1       41
# 2       56
# 6      636
# 7     2626
# dtype: int64

# %%
x.sort_values(ascending=False)
# Out:
# 7     2626
# 6      636
# 2       56
# 1       41
# 0       19
# 4        5
# 10       5
# 5        3
# 9        3
# 3        2
# 8        1
# dtype: int64

# %%
movies.head(3)
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
#
#    original_title  is_adult  year_of_release runtime                  genres  \
# 11      Gully Boy         0             2019     153             Drama|Music
# 34  Yeh Hai India         0             2017     128  Action|Adventure|Drama
# 37     Article 15         0             2019     130             Crime|Drama
#
# ...

# %%
movies.sort_values('title_x',ascending= False)
# Out:
#                   title_x    imdb_id  \
# 1623             Zubeidaa  tt0255713
# 1224         Zinda (film)  tt0488906
# 560       Zid (2014 film)  tt4228746
# 1312                Zeher  tt0451983
# 1035             Yuvvraaj  tt1105747
# ...                   ...        ...
# 886   Aakrosh (2010 film)  tt1708453
# 1055             68 Pages  tt1151299
# 1135        36 China Town  tt0477252
# 912              3 Idiots  tt1187043
# 1039     1971 (2007 film)  tt0983990
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1224  https://upload.wikimedia.org/wikipedia/en/thum...
# 560   https://upload.wikimedia.org/wikipedia/en/thum...
# 1312  https://upload.wikimedia.org/wikipedia/en/c/ce...
# 1035  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 886   https://upload.wikimedia.org/wikipedia/en/thum...
# 1055  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# By default missing values will be sent to the bottom, but it can be kept at top with a parameter na_position='first'

# %%
# sorting based on multiple columns

movies.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Sort movies based on ascending year first then titles but in the descending order.
# Out:
#                       title_x     imdb_id  \
# 1623                 Zubeidaa   tt0255713
# 1573      Yaadein (2001 film)   tt0248617
# 1621                  Tum Bin   tt0290326
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1601         Maya (2001 film)   tt0299027
# ...                       ...         ...
# 112   Bhavesh Joshi Superhero   tt6129302
# 99                   Baaghi 2   tt6843812
# 87                    Aiyaary   tt6774212
# 11                  Gully Boy   tt2395469
# 37          Article 15 (film)  tt10324144
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1573  https://upload.wikimedia.org/wikipedia/en/thum...
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
# 1601  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 112   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ### sort_index()
#
# Sorts the indexes. Works in both series and df.

# %%
marks = {
    'maths' : 67,
    'hindi' : 24,
    'english' : 89,
    'science' : 58
}
marks = pd.Series(marks)

# %%
marks
# Out:
# maths      67
# hindi      24
# english    89
# science    58
# dtype: int64

# %%
marks.sort_index() #sorts the index alphabetically
# Out:
# english    89
# hindi      24
# maths      67
# science    58
# dtype: int64

# %%
movies.sort_index(ascending=False).head(3)
# Out:
#                       title_x    imdb_id  \
# 1623                 Zubeidaa  tt0255713
# 1621                  Tum Bin  tt0290326
# 1607  Nayak (2001 Hindi film)  tt0291376
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 1607  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1623             https://en.wikipedia.org/wiki/Zubeidaa
# 1621              https://en.wikipedia.org/wiki/Tum_Bin
# 1607  https://en.wikipedia.org/wiki/Nayak_(2001_Hind...
#
#                                title_y                    original_title  \
# 1623                          Zubeidaa                          Zubeidaa
# 1621  Tum Bin...: Love Will Find a Way  Tum Bin...: Love Will Find a Way
# 1607              Nayak: The Real Hero              Nayak: The Real Hero
#
# ...

# %% [markdown]
# ### .set_index()
#
# Applicable in dataframe -> inplace

# %%
batsman = pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-pandas2/batsman_runs_ipl.csv')

# %%
batsman.set_index('batter')
batsman.set_index('batter', inplace =True)

# %% [markdown]
# ### .rest_index()
#
# This works on both series and dataframe

# %%
batsman.head(3)
# Out:
#                 batsman_run
# batter
# A Ashish Reddy          280
# A Badoni                161
# A Chandila                4

# %%
batsman.reset_index(inplace=True)

# %%
batsman.head(3)
# Out:
#            batter  batsman_run
# 0  A Ashish Reddy          280
# 1        A Badoni          161
# 2      A Chandila            4

# %%
# Using on series
marks
# Out:
# maths      67
# hindi      24
# english    89
# science    58
# dtype: int64

# %%
marks.reset_index(name='Scores') #use scores to set a column name
# Out:
#      index  Scores
# 0    maths      67
# 1    hindi      24
# 2  english      89
# 3  science      58

# %%
type(marks.reset_index()) #reset_index on a series outputs a dataframe
# Out:
# pandas.DataFrame

# %% [markdown]
# ### Rename
#
# Works on dataframe

# %%
movies.head(3)
# Out:
#               title_x     imdb_id  \
# 11          Gully Boy   tt2395469
# 34      Yeh Hai India   tt5525846
# 37  Article 15 (film)  tt10324144
#
#                                           poster_path  \
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://upload.wikimedia.org/wikipedia/en/thum...
# 37  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                           wiki_link        title_y  \
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# 34      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# 37  https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
#
#    original_title  is_adult  year_of_release runtime                  genres  \
# 11      Gully Boy         0             2019     153             Drama|Music
# 34  Yeh Hai India         0             2017     128  Action|Adventure|Drama
# 37     Article 15         0             2019     130             Crime|Drama
#
# ...

# %%
movies.set_index('title_x',inplace=True)

# %%
movies.head(3)
# Out:
#                       imdb_id  \
# title_x
# Gully Boy           tt2395469
# Yeh Hai India       tt5525846
# Article 15 (film)  tt10324144
#
#                                                          poster_path  \
# title_x
# Gully Boy          https://upload.wikimedia.org/wikipedia/en/thum...
# Yeh Hai India      https://upload.wikimedia.org/wikipedia/en/thum...
# Article 15 (film)  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                          wiki_link  \
# title_x
# Gully Boy                  https://en.wikipedia.org/wiki/Gully_Boy
# Yeh Hai India          https://en.wikipedia.org/wiki/Yeh_Hai_India
# Article 15 (film)  https://en.wikipedia.org/wiki/Article_15_(film)
#
#                          title_y original_title  is_adult  year_of_release  \
# title_x
# Gully Boy              Gully Boy      Gully Boy         0             2019
# Yeh Hai India      Yeh Hai India  Yeh Hai India         0             2017
# ...

# %%
movies.rename(columns={'imdb_id':'imdb'},inplace=True) #change column name by passing one or multiple values in a dictonary.

# %%
movies.head(3)
# Out:
#                          imdb  \
# title_x
# Gully Boy           tt2395469
# Yeh Hai India       tt5525846
# Article 15 (film)  tt10324144
#
#                                                          poster_path  \
# title_x
# Gully Boy          https://upload.wikimedia.org/wikipedia/en/thum...
# Yeh Hai India      https://upload.wikimedia.org/wikipedia/en/thum...
# Article 15 (film)  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                          wiki_link  \
# title_x
# Gully Boy                  https://en.wikipedia.org/wiki/Gully_Boy
# Yeh Hai India          https://en.wikipedia.org/wiki/Yeh_Hai_India
# Article 15 (film)  https://en.wikipedia.org/wiki/Article_15_(film)
#
#                          title_y original_title  is_adult  year_of_release  \
# title_x
# Gully Boy              Gully Boy      Gully Boy         0             2019
# Yeh Hai India      Yeh Hai India  Yeh Hai India         0             2017
# ...

# %%
movies.rename(index={'Article 15 (film)':'Article15'},inplace=True) #can also change index names
movies.head(3)
# Out:
#                      imdb                                        poster_path  \
# title_x
# Gully Boy       tt2395469  https://upload.wikimedia.org/wikipedia/en/thum...
# Yeh Hai India   tt5525846  https://upload.wikimedia.org/wikipedia/en/thum...
# Article15      tt10324144  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                      wiki_link        title_y  \
# title_x
# Gully Boy              https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# Yeh Hai India      https://en.wikipedia.org/wiki/Yeh_Hai_India  Yeh Hai India
# Article15      https://en.wikipedia.org/wiki/Article_15_(film)     Article 15
#
#               original_title  is_adult  year_of_release runtime  \
# title_x
# Gully Boy          Gully Boy         0             2019     153
# Yeh Hai India  Yeh Hai India         0             2017     128
# Article15         Article 15         0             2019     130
#
# ...

# %% [markdown]
# ### Checking of missing values in data
#
# Works on both series and df.

# %%
movies = pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-pandas2/movies.csv')

# %% [markdown]
# ### isnull()

# %%
movies[movies.isnull()].count()
# Out:
# title_x             0
# imdb_id             0
# poster_path         0
# wiki_link           0
# title_y             0
# original_title      0
# is_adult            0
# year_of_release     0
# runtime             0
# genres              0
# imdb_rating         0
# imdb_votes          0
# story               0
# summary             0
# tagline             0
# actors              0
# wins_nominations    0
# release_date        0
# dtype: int64

# %% [markdown]
# ### notnull()

# %%
ipl[ipl['City'].notnull()].head(3) # all values that are not null.
# Out:
#      ID       City        Date Season  MatchNumber  \
# 0  1480  Ahmedabad  2022-05-29   2022        Final
# 1  1479  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1478    Kolkata  2022-05-25   2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# ...

# %% [markdown]
# ### hasnans()
#
# Gives a boolean summary if there is a missing value in a series or column.

# %%
ipl['Team1'].hasnans
# Out:
# False

# %% [markdown]
# ### .dropna()
#
# Drops all the rows with a missing value (even a single missing value will remove that row). Works on series and df

# %%
student_data.dropna() #default parameter (how = 'any)
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
student_data.dropna(how = 'all') #if all values are missing (how = 'any)
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
# removing rows based on a value from missing column

student_data.dropna(subset=['package']) 
# Will drop only those rows where a missing value occurs in the package column
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %% [markdown]
# ### fillna()
#
# Insead of droping use a value to fill missing data.
# Works on both series and df.

# %%
movies[movies['poster_path'].isnull()].head(2)
# Out:
#            title_x    imdb_id poster_path  \
# 1    Battalion 609  tt9472208         NaN
# 4  Evening Shadows  tt6028796         NaN
#
#                                        wiki_link          title_y  \
# 1    https://en.wikipedia.org/wiki/Battalion_609    Battalion 609
# 4  https://en.wikipedia.org/wiki/Evening_Shadows  Evening Shadows
#
#     original_title  is_adult  year_of_release runtime genres  imdb_rating  \
# 1    Battalion 609         0             2019     131    War          4.1
# 4  Evening Shadows         0             2018     102  Drama          7.3
#
#    imdb_votes                                              story  \
# 1          73  The story revolves around a cricket match betw...
# 4         280  While gay rights and marriage equality has bee...
#
#                                              summary tagline  \
# 1  The story of Battalion 609 revolves around a c...     NaN
# 4  Under the 'Evening Shadows'  truth often plays...     NaN
#
# ...

# %%
# these poster paths are missing, instead of removing these rows lets fill it with something.
movies['poster_path'].fillna('missing_link')
# Out:
# 0       https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                            missing_link
# 2       https://upload.wikimedia.org/wikipedia/en/thum...
# 3       https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                            missing_link
#                               ...
# 1624    https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625    https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                         missing_link
# 1627    https://upload.wikimedia.org/wikipedia/en/thum...
# 1628    https://upload.wikimedia.org/wikipedia/en/thum...
# Name: poster_path, Length: 1629, dtype: str

# %% [markdown]
# missing data can be filled with different strategies.
#
# 1. forward fill
# 2. backward fill
# 3. mean()
# 4. mode()
# etc...

# %% [markdown]
# ### drop_duplicates()
#
# Remove duplicate values. work on series and df.

# %%
marks.drop_duplicates()
# marks.drop_duplicates(keep='last') # keeps the last occurance, default 1st
# Out:
# maths      67
# hindi      24
# english    89
# science    58
# dtype: int64

# %%
marks.duplicated() # If there is a missing duplicate value.
# Out:
# maths      False
# hindi      False
# english    False
# science    False
# dtype: bool

# %% [markdown]
# ### drop()
#
# Deletes rows/columns
#
# Works on both series and df.

# %%
marks
# Out:
# maths      67
# hindi      24
# english    89
# science    58
# dtype: int64

# %%
marks.drop(index=['maths'])
# Out:
# hindi      24
# english    89
# science    58
# dtype: int64

# %%
student_dict.drop(columns=['package'])
# Out:
#        iq  marks
# name
# uc    100     80
# ac     90     70
# vk    120    100
# sh     80     50

# %%
student_dict.drop(index = ['uc'])
# Out:
#        iq  marks  package
# name
# ac     90     70        7
# vk    120    100       14
# sh     80     50        2
