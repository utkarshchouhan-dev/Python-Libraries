# %% [markdown]
# # Groupby()

# %% [markdown]
# - We use groupby on categorical variables.

# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-groupby/imdb-top-1000.csv')
ipl = pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-pandas2/ipl-matches.csv')

# %%
movies.head(3)
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0

# %%
movies.shape
# Out:
# (1000, 10)

# %%
genres = movies.groupby('Genre') #We create based on columns.

# %%
print(genres) #This is telling the datatype but not the actual values. Let's ask some questions to this groupby object.

# %%
# applying built-in aggregation functions
genres.sum(numeric_only=True).sort_values('No_of_Votes',ascending=False)
# this give a data frame. If you notice the indexes are now genres.
# Out:
#            Runtime  IMDB_Rating  No_of_Votes         Gross  Metascore
# Genre
# Action       22196       1367.3     72282412  3.263226e+10    10499.0
# Drama        36049       2299.7     61367304  3.540997e+10    19208.0
# Crime        13524        857.8     33533615  8.452632e+09     6706.0
# Comedy       17380       1224.7     27620327  1.566387e+10     9840.0
# Biography    11970        698.6     24006844  8.276358e+09     6023.0
# Adventure     9656        571.5     22576163  9.496922e+09     5020.0
# Animation     8166        650.3     21978630  1.463147e+10     6082.0
# Mystery       1429         95.7      4203004  1.256417e+09      633.0
# Horror        1123         87.0      3742556  1.034649e+09      880.0
# Western        593         33.4      1289665  5.822151e+07      313.0
# Family         215         15.6       551221  4.391106e+08      158.0
# Film-Noir      312         23.9       367215  1.259105e+08      287.0
# ...

# %% [markdown]
# All min/max/std/sum/prod/var functions will work on this groupby object.

# %%
genres.min()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                                 300          1924       45
# Adventure            2001: A Space Odyssey          1925       88
# Animation                            Akira          1940       71
# Biography                 12 Years a Slave          1928       93
# Comedy                (500) Days of Summer          1921       68
# Crime                         12 Angry Men          1931       80
# Drama                                 1917          1925       64
# Family          E.T. the Extra-Terrestrial          1971      100
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                Shadow of a Doubt          1941      100
# Horror                               Alien          1933       71
# Mystery                          Dark City          1938       96
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
genres.mean(numeric_only=True)
# Out:
#               Runtime  IMDB_Rating    No_of_Votes         Gross  Metascore
# Genre
# Action     129.046512     7.949419  420246.581395  1.897224e+08  73.419580
# Adventure  134.111111     7.937500  313557.819444  1.319017e+08  78.437500
# Animation   99.585366     7.930488  268032.073171  1.784326e+08  81.093333
# Biography  136.022727     7.938636  272805.045455  9.404952e+07  76.240506
# Comedy     112.129032     7.901290  178195.658065  1.010572e+08  78.720000
# Crime      126.392523     8.016822  313398.271028  7.899656e+07  77.080460
# Drama      124.737024     7.957439  212343.612457  1.225259e+08  79.701245
# Family     107.500000     7.800000  275610.500000  2.195553e+08  79.000000
# Fantasy     85.000000     8.000000   73111.000000  3.913633e+08        NaN
# Film-Noir  104.000000     7.966667  122405.000000  4.197018e+07  95.666667
# Horror     102.090909     7.909091  340232.363636  9.405902e+07  80.000000
# ...

# %%
genres.std(numeric_only=True)
# Out:
#              Runtime  IMDB_Rating    No_of_Votes         Gross  Metascore
# Genre
# Action     28.500706     0.304258  432946.814748  2.256724e+08  12.421252
# Adventure  33.317320     0.229781  301188.347642  1.697543e+08  12.345393
# Animation  14.530471     0.253221  262173.231571  2.091840e+08   8.813646
# Biography  25.514466     0.267140  271284.191372  1.363251e+08  11.028187
# Comedy     22.946213     0.228771  188653.570564  1.946513e+08  11.829160
# Crime      27.689231     0.335477  373999.730656  1.571191e+08  13.099102
# Drama      27.740490     0.267229  305554.162841  2.201164e+08  12.744687
# Family     10.606602     0.000000  137008.302816  3.048412e+08  16.970563
# Fantasy    12.727922     0.141421   22179.111299  7.606861e+07        NaN
# Film-Noir   4.000000     0.152753   54649.083277  7.048472e+07   1.527525
# Horror     13.604812     0.311302  234883.508691  9.965017e+07  15.362291
# Mystery    14.475423     0.310791  404621.915297  1.567524e+08  18.604435
# ...

# %%
genres.max()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                                 Yôjinbô          2019      321
# Adventure                           Zombieland            PG      228
# Animation          Ôkami kodomo no Ame to Yuki          2020      137
# Biography                              Zerkalo          2020      209
# Comedy                Zindagi Na Milegi Dobara          2020      188
# Crime                        À bout de souffle          2019      229
# Drama                                Zwartboek          2020      242
# Family     Willy Wonka & the Chocolate Factory          1982      115
# Fantasy                              Nosferatu          1922       94
# Film-Noir                        The Third Man          1949      108
# Horror                               The Thing          2017      122
# Mystery                                Vertigo          2012      138
# ...

# %% [markdown]
# ### Practice Questions

# %%
# find the top 3 genres by total earning.

movies.groupby('Genre').sum(numeric_only=True)['Gross'].sort_values(ascending=False).head(3)

# Group the data based on genres, find the sum of the group by object, only keep the gross column, it will give a pandas series,
# sort the series in descending order and keep top 3.
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# same as above, but optimized.
movies.groupby('Genre')['Gross'].sum(numeric_only=True).sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
# find the genre with highest avg IMDB rating.

movies.groupby('Genre')['IMDB_Rating'].mean().sort_values(ascending=False)
# Out:
# Genre
# Western      8.350000
# Crime        8.016822
# Fantasy      8.000000
# Mystery      7.975000
# Film-Noir    7.966667
# Drama        7.957439
# Action       7.949419
# Biography    7.938636
# Adventure    7.937500
# Animation    7.930488
# Horror       7.909091
# Comedy       7.901290
# Family       7.800000
# Thriller     7.800000
# Name: IMDB_Rating, dtype: float64

# %%
# find the number of movies done by each actor.

movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # find the number of movies done by each actor.
# ----> 3 movies.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
#
# NameError: name 'movies' is not defined

# %% [markdown]
# ## Groupby Attributes

# %% [markdown]
# ### Find total number of group/ len of groupby object.

# %%
len(genres) # there are 14 unique groups
# Out:
# 14

# %%
# we can also find the len by using nunique function on the original column. Cause all unique values will form same number of groups.

movies['Genre'].nunique()
# Out:
# 14

# %% [markdown]
# ### Find items in each group.

# %%
genres.size() # number of items in each individual group.
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %% [markdown]
# ### .first() , .last() , .nth()

# %%
genres.first() #First movie from each genre.
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                     The Dark Knight          2008      152
# Adventure                     Interstellar          2014      169
# Animation    Sen to Chihiro no kamikakushi          2001      125
# Biography                 Schindler's List          1993      195
# Comedy                        Gisaengchung          2019      132
# Crime                        The Godfather          1972      175
# Drama             The Shawshank Redemption          1994      142
# Family          E.T. the Extra-Terrestrial          1982      115
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                    The Third Man          1949      104
# Horror                              Psycho          1960      109
# Mystery                            Memento          2000      113
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
genres.last() #Last movie from each genre
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
genres.nth(5) #Finds sixth movie from each genre. Those groups with less than 6 movies won't show up.
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 14                                          The Matrix          1999      136
# 24                                 Saving Private Ryan          1998      169
# 25                                      The Green Mile          1999      189
# 54                           Ayla: The Daughter of War          2017      125
# 61                                                Coco          2017      105
# 78   Dr. Strangelove or: How I Learned to Stop Worr...          1964       95
# 116                                 Lawrence of Arabia          1962      228
# 393                                     Twelve Monkeys          1995      129
# 707                                      The Innocents          1961      100
#
#          Genre  IMDB_Rating          Director            Star1  No_of_Votes  \
# 14      Action          8.7    Lana Wachowski  Lilly Wachowski      1676426
# ...

# %% [markdown]
# ### .getgroup()

# %%
# Find all the items from a particular group.

# Question: Find out all the movies from genre Horror.

genres.get_group('Horror')
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 49                     Psycho          1960      109  Horror          8.5
# 75                      Alien          1979      117  Horror          8.4
# 271                 The Thing          1982      109  Horror          8.1
# 419              The Exorcist          1973      122  Horror          8.0
# 544  Night of the Living Dead          1968       96  Horror          7.9
# 707             The Innocents          1961      100  Horror          7.8
# 724                   Get Out          2017      104  Horror          7.7
# 844                 Halloween          1978       91  Horror          7.7
# 876         The Invisible Man          1933       71  Horror          7.7
# 932                       Saw          2004      103  Horror          7.6
# 948                The Others          2001      101  Horror          7.6
#
#                Director             Star1  No_of_Votes        Gross  Metascore
# ...

# %%
movies[movies['Genre'] == "Horror"] # we can also do filtering by boolean indexing, but groupby is more efficient.
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 49                     Psycho          1960      109  Horror          8.5
# 75                      Alien          1979      117  Horror          8.4
# 271                 The Thing          1982      109  Horror          8.1
# 419              The Exorcist          1973      122  Horror          8.0
# 544  Night of the Living Dead          1968       96  Horror          7.9
# 707             The Innocents          1961      100  Horror          7.8
# 724                   Get Out          2017      104  Horror          7.7
# 844                 Halloween          1978       91  Horror          7.7
# 876         The Invisible Man          1933       71  Horror          7.7
# 932                       Saw          2004      103  Horror          7.6
# 948                The Others          2001      101  Horror          7.6
#
#                Director             Star1  No_of_Votes        Gross  Metascore
# ...

# %% [markdown]
# ### .groups attribute

# %%
genres.groups # this returns a dictonary, where key is group name and the value is a list indexes of those that data that belong to the group.
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
movies.iloc[2]
# Out:
# Series_Title       The Dark Knight
# Released_Year                 2008
# Runtime                        152
# Genre                       Action
# IMDB_Rating                    9.0
# Director         Christopher Nolan
# Star1               Christian Bale
# No_of_Votes                2303232
# Gross                  534858444.0
# Metascore                     84.0
# Name: 2, dtype: object

# %% [markdown]
# ### .describe() , .sample() , .nunique()

# %%
genres.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
genres.sample() # a random movie from each genre
# Out:
#                      Series_Title Released_Year  Runtime      Genre  \
# 582                     Rogue One          2016      133     Action
# 513               Children of Men          2006      109  Adventure
# 405                         Akira          1988      124  Animation
# 770                       Control          2007      122  Biography
# 562        The Philadelphia Story          1940      112     Comedy
# 833             Der Name der Rose          1986      130      Crime
# 880                      Nelyubov          2017      127      Drama
# 688    E.T. the Extra-Terrestrial          1982      115     Family
# 568                     Nosferatu          1922       94    Fantasy
# 309                 The Third Man          1949      104  Film-Noir
# 49                         Psycho          1960      109     Horror
# 220                       Kahaani          2012      122    Mystery
# 700               Wait Until Dark          1967      108   Thriller
# ...

# %%
genres.sample(2,replace=True) # 2 a random movie from each genre, if there are less than 3 movies in a genre, it will repeat it.
# Out:
#                             Series_Title Released_Year  Runtime      Genre  \
# 431              Per un pugno di dollari          1964       99     Action
# 42                                  Léon          1994      110     Action
# 514                        Almost Famous          2000      122  Adventure
# 553                        The Searchers          1956      119  Adventure
# 592                           Big Hero 6          2014      102  Animation
# 992                      The Jungle Book          1967       78  Animation
# 7                       Schindler's List          1993      195  Biography
# 346                    The King's Speech          2010      118  Biography
# 379                 Yeopgijeogin geunyeo          2001      137     Comedy
# 826                          Barton Fink          1991      116     Comedy
# 791                    Road to Perdition          2002      117      Crime
# ...

# %%
genres.nunique() #number of unique values for all columns in each genre.
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %% [markdown]
# ### Custom aggregation using .agg()

# %%
### Some times it doesn't makes sense to use same aggregation function on all the columns, like it may make sense to find the sum of revenue of all movies but not so much for the meta score.

### So we can apply multiple agg functions at once.

genres.agg({
    'Runtime':['mean','median'],
    'IMDB_Rating':'mean',
    'Gross':['sum','mean'],
    'Metascore':'min'
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 ### Some times it doesn't makes sense to use same aggregation function on all the columns, like it may make sense to find the sum of revenue of all movies but not so much for the meta score.
#       2
#       3 ### So we can apply multiple agg functions at once.
# ----> 5 genres.agg({
#       6     'Runtime':['mean','median'],
#       7     'IMDB_Rating':'mean',
#       8     'Gross':['sum','mean'],
#       9     'Metascore':'min'
#      10 })
#
# NameError: name 'genres' is not defined

# %% [markdown]
# ### Looping on groups
#
# Find top rated movie in each genre and store them into a new dataframe.

# %%
top_movies_by_genre = pd.DataFrame(columns=movies.columns) # creating an empty dataframe
top_movies_by_genre
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Runtime, Genre, IMDB_Rating, Director, Star1, No_of_Votes, Gross, Metascore]
# Index: []

# %%
for group,data in genres:
    
    top_movies_by_genre = pd.concat([top_movies_by_genre,(data[data["IMDB_Rating"] == data['IMDB_Rating'].max()])])

# %%
top_movies_by_genre
# Out:
#                             Series_Title Released_Year Runtime      Genre  \
# 2                        The Dark Knight          2008     152     Action
# 21                          Interstellar          2014     169  Adventure
# 23         Sen to Chihiro no kamikakushi          2001     125  Animation
# 7                       Schindler's List          1993     195  Biography
# 19                          Gisaengchung          2019     132     Comedy
# 26                       La vita è bella          1997     116     Comedy
# 1                          The Godfather          1972     175      Crime
# 0               The Shawshank Redemption          1994     142      Drama
# 688           E.T. the Extra-Terrestrial          1982     115     Family
# 698  Willy Wonka & the Chocolate Factory          1971     100     Family
# 321         Das Cabinet des Dr. Caligari          1920      76    Fantasy
# 309                        The Third Man          1949     104  Film-Noir
# ...
