# %% [markdown]
# # Welcome to Pandas

# %% [markdown]
# Official Pandas Documentation
#
# https://pandas.pydata.org/docs/user_guide/index.html#user-guide

# %% [markdown]
# ## Installing and Importing Pandas

# %%
# !pip3 install pandas -q

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## What is Pandas?
#
# Pandas is a fast, powerful, flexible and easy to use opensource data analysis and manipulation tool, built on top of the Python programming language.
#
# ### Basic data structures in pandas
#
# <b>Pandas provides two types of classes for handling data: </b>
#
# Series: a one-dimensional labeled array holding data of any type
# such as integers, strings, Python objects etc.
#
# DataFrame: a two-dimensional data structure that holds data like a two-dimension array or a table with rows and columns. Like in excel.

# %% [markdown]
# # Series

# %% [markdown]
# ## Creating Series

# %%
# string
country = pd.Series(['india','germany','usa','japan','russia'])

print(country)

# there is always an auto generated index attached to series.
# Out:
# 0      india
# 1    germany
# 2        usa
# 3      japan
# 4     russia
# dtype: str

# %%
# integers
runs = pd.Series([12,41,25,66,75,34],dtype='uint16')
print(runs)
# Out:
# 0    12
# 1    41
# 2    25
# 3    66
# 4    75
# 5    34
# dtype: uint16

# %%
# using custom index
marks = [67,35,86,69]
subjects = ['maths','english','science','hindi']

uc_marks = print(pd.Series(marks,index=subjects,name = "Utkarsh's Marks"))

#We can set custom index names by using index parameter.
#We can assign a referable name to series object by using name parameter.
# Out:
# maths      67
# english    35
# science    86
# hindi      69
# Name: Utkarsh's Marks, dtype: int64

# %%
# series from dict

marks = {
    'maths' : 67,
    'english' : 87,
    'science' : 56,
    'hindi' : 90
}
uc_marks = pd.Series(marks,name='Utkarsh ke marks')
print(uc_marks)
# Out:
# maths      67
# english    87
# science    56
# hindi      90
# Name: Utkarsh ke marks, dtype: int64

# %% [markdown]
# ## Series Attributes
# 1. size
# 2. dtype
# 3. name
# 4. index
# 5. values
# 6. is_unique

# %%
country = pd.Series(['india','germany','usa','japan','russia'])

print(country)
# Out:
# 0      india
# 1    germany
# 2        usa
# 3      japan
# 4     russia
# dtype: str

# %%
# shape and size
print(country.shape)
print(country.size)
# Out:
# (5,)
# 5

# %%
# dtype

print(country.dtype)
# Out:
# str

# %%
# name
print(uc_marks.name)
# Out:
# Utkarsh ke marks

# %%
# is_unique -> True - If all items are unique, else False

print(uc_marks.is_unique)
print(pd.Series([1,2,3,4,4,1,9]).is_unique)
# Out:
# True
# False

# %%
# index

print(uc_marks.index)
print(runs.index)
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='str')
# RangeIndex(start=0, stop=6, step=1)

# %%
# values -> outputs a numpy array

uc_marks.values
# Out:
# array([67, 87, 56, 90])

# %% [markdown]
# ### Series using read_csv (!! Most Important and Used)

# %%
# with one column

subs = pd.read_csv("/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-pandas/subs.csv")

subs = subs.squeeze()

print(subs)

type(subs) #this creates a data frame, unless we use squeeze parameter.
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64
# pandas.Series

# %%
# with 2 columns

# read_csv always outputs a dataframe, so we use squeeze to make it a series

kohli = pd.read_csv("/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-pandas/kohli_ipl.csv", index_col='match_no')
bollywood = pd.read_csv("/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-pandas/bollywood.csv",index_col='movie').squeeze()

kohli = kohli.squeeze()

print(kohli)
print(bollywood)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# ## Series Methods

# %%
# head
subs.head(3) #default 5
# Out:
# 0    48
# 1    57
# 2    40
# Name: Subscribers gained, dtype: int64

# %%
# tail
subs.tail() #default 5
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
# tail
kohli.tail(8)
# Out:
# match_no
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample -> Randomly selected samples (good if data is biased)
bollywood.sample(5) #Default 1
# Out:
# movie
# Krazzy 4                Juhi Chawla
# Shikhar (film)           Ajay Devgn
# Bheja Fry (film)       Vinay Pathak
# Don't Stop Dreaming    Rishi Kapoor
# Total Dhamaal            Ajay Devgn
# Name: lead, dtype: str

# %%
# value_count -> Counts the frequency of every item in the dataset.

bollywood.value_counts() #Number of movies done by each actor (desc order)
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values() - Doesn't affects original array. unless inplace = True

print(kohli.sort_values())
print(kohli.sort_values(ascending=False),'\n') #For descending order
print(kohli.sort_values(ascending=False).head(1).values[0])
# kohli.sort_values(inplace=True) # This will change the original array. Use carefully.
# Out:
# match_no
# 87       0
# 211      0
# 207      0
# 206      0
# 91       0
#       ...
# 164    100
# 120    100
# 123    108
# 126    109
# 128    113
# Name: runs, Length: 215, dtype: int64
# match_no
# 128    113
# 126    109
# 123    108
# 164    100
# 120    100
#       ...
# 93       0
# 211      0
# 130      0
# 8        0
# 135      0
# Name: runs, Length: 215, dtype: int64
#
# 113

# %%
# sort_index() -> Insead of values it will sort based on index.

print(bollywood.sort_index()) # ascending = False
# bollywood.sort_index(inplace=True) # Changes the original array. Be Careful
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# ## Series Maths Methods

# %%
# count - Counts total number of values present inside a series, only non missing values.
kohli.count()
# Out:
# np.int64(215)

# %%
# sum
subs.sum()
# Out:
# np.int64(49510)

# %%
# product
pd.Series([1,2,3,4,5]).prod() #If result is 0, there might be a zero in the dataset.
# Out:
# np.int64(120)

# %% [markdown]
# ### mean, media, mode, std, var

# %%
#mean
subs.mean()
# Out:
# np.float64(135.64383561643837)

# %%
#median
kohli.median()
# Out:
# np.float64(24.0)

# %%
#mode
bollywood.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: str

# %%
#std
subs.std()
# Out:
# np.float64(62.6750230372527)

# %%
#var
subs.var()
# Out:
# np.float64(3928.1585127201565)

# %%
#min.max
print(subs.max())
print(subs.min())
# Out:
# 396
# 33

# %%
# describe - statistical summary
kohli.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# ## Series Indexing and Slicing

# %%
# integer indexing
x = pd.Series([12,14,14,35,46,57,58,79,9])
print(x[1])
# Out:
# 14

# %%
# Negative indexing
# print(x[-1]) - Negative indexing doesn't works in series.

# %%
# string indexing
bollywood['Bombairiya']
# Out:
# 'Radhika Apte'

# %%
# Slicing
kohli[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
# Negative Slicing
kohli[-5:] #Can also put step-size
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# Fancy Indexing
kohli[[1,2,5]]
# Out:
# match_no
# 1     1
# 2    23
# 5     1
# Name: runs, dtype: int64

# %% [markdown]
# ## Editing Items in Series

# %%
# using indexing
print(uc_marks,'\n')
uc_marks['maths'] = 100
print(uc_marks,'\n')
# Out:
# maths      67
# english    87
# science    56
# hindi      90
# Name: Utkarsh ke marks, dtype: int64
#
# maths      100
# english     87
# science     56
# hindi       90
# Name: Utkarsh ke marks, dtype: int64

# %%
# fancy indexing
# kohli[[1,4,6]] = [0,0,0] #modifies original data
print(kohli[[1,4,6]])
# Out:
# match_no
# 1     1
# 4    12
# 6     9
# Name: runs, dtype: int64

# %% [markdown]
# ## Series with Python Functionalities

# %% [markdown]
# ### len/type/dir/sorted/max/min

# %%
kohli
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# len - Total number of items
len(kohli)
# Out:
# 215

# %%
#type - Prints data type
type(kohli)
# Out:
# pandas.Series

# %%
# dir - prints all methods, attributes, magic methods of an object
# usually output is long

# dir(kohli)

# %%
#sorted - Sorts but outputs a list, that's why not frequently used.

sorted(uc_marks)
# Out:
# [56, 87, 90, 100]

# %%
#min and max
print(min(kohli))
print(max(kohli))
# Out:
# 0
# 113

# %% [markdown]
# ### Type Conversion

# %%
# converting to list
list(uc_marks)
# Out:
# [100, 87, 56, 90]

# %%
# converting to dict
dict(marks)
# Out:
# {'maths': 67, 'english': 87, 'science': 56, 'hindi': 90}

# %%
# using astype
import sys

print((kohli.dtype))
print(sys.getsizeof(kohli))

vk = kohli.astype('uint16')

print(vk.dtype)
print(sys.getsizeof(vk))
# Out:
# int64
# 1884
# uint16
# 594

# %% [markdown]
# ### Membership Operator (in , not in)

# %%
"The Last Lear" in bollywood
# Out:
# True

# %%
"The Last Lear" not in bollywood #False - because it is there
# Out:
# False

# %%
"Alia Bhatt" in bollywood #False - but she is there.
# Out:
# False

# %%
# by default membership operators work on index, to find in values use:

"Alia Bhatt" in bollywood.values #yay
# Out:
# True

# %% [markdown]
# ### Looping

# %%
# looping
for i in bollywood:
    print(i)

# by default works on values.
# if index is required to be looped use

# for i in bollywood.index:
#     print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %% [markdown]
# ### Arithmetic Operators

# %%
# All arithmetic operators work, and if scaler is given 
# it will be broadcasted accordingly.

print(100 - uc_marks)
print(uc_marks * uc_marks)
# Out:
# maths       0
# english    13
# science    44
# hindi      10
# Name: Utkarsh ke marks, dtype: int64
# maths      10000
# english     7569
# science     3136
# hindi       8100
# Name: Utkarsh ke marks, dtype: int64

# %% [markdown]
# ### Relational Operators

# %%
kohli > 50 # output is a boolean series
kohli <= 50 # output is a boolean series
# Out:
# match_no
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
#        ...
# 211     True
# 212     True
# 213    False
# 214     True
# 215     True
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# ### Boolean Indexing

# %%
kohli[kohli >= 100].count() # number of centuries
# Out:
# np.int64(5)

# %%
kohli[kohli == 0].size # out at zero 😂 = duck
# Out:
# 9

# %%
# Count number of days where subs count is greater than 200.

print(subs[subs >= 200].size)
# Out:
# 59

# %%
# Actors who have done more than 20 movies

movies = bollywood.value_counts()
movies[movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %%
bollywood.value_counts()[bollywood.value_counts() > 20]

#same as above
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
bollywood.value_counts().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
bollywood.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: >

# %% [markdown]
# ## Some Important Series Methods

# %% [markdown]
# ### between()
# If a value exist in a given range.

# %%
kohli[kohli.between(49,101)].size
# Out:
# 48

# %% [markdown]
# ### clip()

# %%
# example values < 100 will become 100, more than 150 
# will become 200, rest will be uneffected.

subs.clip(100,150)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    150
# 361    150
# 362    150
# 363    144
# 364    150
# Name: Subscribers gained, Length: 365, dtype: int64

# %% [markdown]
# ### drop_duplicates() and duplicated()
#
# Removes the duplicate values.

# %%
# drop_duplicates

temp = pd.Series([12,51,73,44,74,12,52,74])
print(temp.drop_duplicates()) # keeps first occurance only
# if you wanna keep last occurance, use drop_duplicates(keep = 'last)
# Out:
# 0    12
# 1    51
# 2    73
# 3    44
# 4    74
# 6    52
# dtype: int64

# %%
bollywood.drop_duplicates() #Only kept 1 movie of every actor
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: str

# %%
# To check if data has duplicates.

temp.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
# To check if data has duplicates.

temp.duplicated().sum() # This means 2 duplicate values
# Out:
# np.int64(2)

# %%
# To check if data has duplicates.

temp.duplicated().mean().mean() * 100 # %tage of duplicate values in dataset.
# Out:
# np.float64(25.0)

# %% [markdown]
# ### To count number of items we can use:
# - .count() - It will count all the non-missing (non-null) values
# - .size - All items (including nulls)

# %%
temp = pd.Series([1,2,4,np.nan,8,np.nan,24,2,54,525,25,np.nan,25])
print(temp)
# Out:
# 0       1.0
# 1       2.0
# 2       4.0
# 3       NaN
# 4       8.0
# 5       NaN
# 6      24.0
# 7       2.0
# 8      54.0
# 9     525.0
# 10     25.0
# 11      NaN
# 12     25.0
# dtype: float64

# %%
temp.size
# Out:
# 13

# %%
print(temp.count())
# Out:
# 10

# %% [markdown]
# ### isnull()

# %%
temp.isnull() # gives a boolean series
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# dtype: bool

# %%
temp[temp.isnull()] #masking to filer null values
# Out:
# 3    NaN
# 5    NaN
# 11   NaN
# dtype: float64

# %%
print(temp.isnull().sum()) #number of missing values
print(temp.isnull().mean() * 100) #Percent of missing values from the data
# Out:
# 3
# 23.076923076923077

# %% [markdown]
# ### Handling Missing Values

# %%
# dropna

temp.dropna() # If you wanna remove NULL values.
# Out:
# 0       1.0
# 1       2.0
# 2       4.0
# 4       8.0
# 6      24.0
# 7       2.0
# 8      54.0
# 9     525.0
# 10     25.0
# 12     25.0
# dtype: float64

# %%
# fillna

temp.fillna(0) # If you don't wanna remove NULL's, and replace with some other value.
# Out:
# 0       1.0
# 1       2.0
# 2       4.0
# 3       0.0
# 4       8.0
# 5       0.0
# 6      24.0
# 7       2.0
# 8      54.0
# 9     525.0
# 10     25.0
# 11      0.0
# 12     25.0
# dtype: float64

# %% [markdown]
# ### isin()

# %%
# isin() - similar to sql in ()

kohli.isin([49,99]) #boolean array
kohli[kohli.isin([49,99])] #mask the boolean array
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %% [markdown]
# ### apply()
#
# Allows to use custom logic on series

# %%
bollywood
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %%
# using our custom function. 

# Example - keep actor first name only and in all capital letters.
bollywood.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: str

# %%
# Example - If subs count on a day is greater than average it's a good day
subs.apply(lambda x:'good day' if x > subs.mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: str

# %% [markdown]
# ### copy()

# %%
new = kohli
new
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new[1] = 10 #changing the value in new 
new
# Out:
# match_no
# 1      10
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
kohli # also changed the value in original data

# this happened because of view. the new variable was not a replica, so changes 
# in that also altered the original data. 

# We can prevent this from happening by using .copy() function.
# Out:
# match_no
# 1      10
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = kohli.copy()
new[1] = 1
kohli[1]
# Out:
# np.int64(10)

# %% [markdown]
# ### Rank

# %%
batsman = pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-pandas2/batsman_runs_ipl.csv')

# %%
batsman['batsman_rank'] = batsman['batsman_run'].rank(ascending=False)
batsman.sort_values('batsman_rank')
# Out:
#            batter  batsman_run  batsman_rank
# 569       V Kohli         6634           1.0
# 462      S Dhawan         6244           2.0
# 130     DA Warner         5883           3.0
# 430     RG Sharma         5881           4.0
# 493      SK Raina         5536           5.0
# ..            ...          ...           ...
# 512   SS Cottrell            0         594.0
# 466     S Kaushik            0         594.0
# 203     IC Pandey            0         594.0
# 467       S Ladda            0         594.0
# 468  S Lamichhane            0         594.0
#
# [605 rows x 3 columns]

# %% [markdown]
# ### Unique
#
# Returns all unique value in a column (only works in series). Also lists multiple missing values as a one NULL value.

# %%
temp.unique()
# use len() to find number of unique values
# or use .nunique
# Out:
# array([  1.,   2.,   4.,  nan,   8.,  24.,  54., 525.,  25.])

# %%
# Number of unique values
# .nunique() -> Doesn't counts the missing value.

temp.nunique()
# Out:
# 8

# %% [markdown]
# <center> <h1> End of File </h1> </center>
