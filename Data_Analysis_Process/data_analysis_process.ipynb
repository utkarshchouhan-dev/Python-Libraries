# %% [markdown]
# # Theory

# %% [markdown]
# ## Data Analysis Process
#
# 1. Data Gathering
# 2. Data Cleaning
# 3. EDA

# %% [markdown]
# ## Data Gathering
#
# 1. Importing data from various sources - Databases, CSV, Excel, txt, Json
# 2. Exporting data to - csv, json, html, database
# 3. Gathering data through API
# 4. Web Scraping

# %% [markdown]
# ## What is Data Analysis
#
# Data analysis is a process of inspecting, cleansing, transforming and modeling data with the goal of discovering useful information. informing conclusions and supporting decision-making. - wikipedia
#
# Steps in data analysis.
#
# 1. Asking the right question.
# 2. Data Wrangling (also called data munching or preprocessing).
# 3. Exploratory Data Analysis
# 4. Drawing Conclusions
# 5. Communicating Results

# %% [markdown]
# ## Step 1 : Asking the right questions
#
# In a company you will get a dataset, and you might be asked a well defined question like "What kind of generes customers love the most?" or maybe an open ended question like  "How can we increase the sales in the next quater"
#
# 1. What features will contribute to my analysis?
# 2. What features are not important for my analysis?
# 3. Which of the features have a strong correlation?
# 4. Do I need data preprocessing?
# 5. What kind of feature manipulation/engineering is required?

# %% [markdown]
# ## Step 2 : Data Wrangling/Munging
#
# Data wrangling, sometimes referred to as data munging, is the process of transforming and mapping data from one "raw" data form into another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics.
#
# 1. Gathering Data
# 2. Assessing Data
# 3. Cleaning Data
#
# ### 2a : Gathering Data
# 1. CSV Files
# 2. API
# 3. Web Scraping
# 4. Databases
#
# ### 2b : Assessing Data
# 1. Finding the number of rows/columns(shape)
# 2. Data types of various columns(info())
# 3. Checking for missing values (info())
# 4. Check for missing data (is_unique)
# 5. Memory occupied by the dataset (into())
# 6. High level mathematical overview of the data (describe())
#
# ### 2c : Cleaning Data
# 1. Missing Data (imputation techniques ?)
# 2. Remove duplicate data (drop_duplicate)
# 3. Incorrect datatype (astype)

# %% [markdown]
# ## Step 3 : Exploratory Data Analysis
#
# 1. Explore your data
# 2. Augment your Data
#
# ### 3a : Exploring Data
# 1. Finding Correlation and Covariance
# 2. Doing univariate and multivariate analysis
# 3. Plotting graphs(data visualization)
#
# ### 3b : Augmenting Data
# There operations are collectively called as Feature Engineering.
# 1. Removing outliers
# 2. Merging Dataframes
# 3. Adding new column

# %% [markdown]
# ## Step 4 : Drawing Conclusions
# 1. Machine Learning
# 2. Inferential Statistics
# 3. Descriptive Analysis

# %% [markdown]
# ## Step 5 : Communicating Results/ Data Storytelling
#
# 1. In person
# 2. Reports
# 3. Blog Posts
# 4. PPTs/Slide decks

# %% [markdown]
# ### All these processes are not meant to be in linear manner, it is possible to jump across the steps.

# %% [markdown]
# # Let's Start

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Working with Excel Files

# %%
df = pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/aug_train.csv')
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %%
# Sep Parameter - if the values are seprated with something else than comma.
# pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/movie_titles_metadata.tsv')

pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/movie_titles_metadata.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'])

# These values are seprated with tabs. Can also use delimiter parameter like delimiter='\t'
# Also as there is no default column names, we can use names parameter to override defaults.
# Out:
#       sno                        name release_year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %%
# Index_col parameter - over ride the default autogenerated index with your own index from a column values.

pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/aug_train.csv',index_col='enrollee_id')
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %%
# header parameter - if headers are treated like first row, use this parameter to fix that.

pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/test.csv', header=1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %%
# use_cols parameter - if you know that, there are only few particular columns are required from the entire dataset.

pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/aug_train.csv',usecols=['enrollee_id','gender','education_level'])
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %%
# squeeze function - by default read_csv generates a dataframe, but if you have a single column that you wanna store as a series, then use this.

pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/aug_train.csv',usecols=['enrollee_id']).squeeze()
# Out:
# 0         8949
# 1        29725
# 2        11561
# 3        33241
# 4          666
#          ...
# 19153     7386
# 19154    31398
# 19155    24576
# 19156     5756
# 19157    23834
# Name: enrollee_id, Length: 19158, dtype: int64

# %%
# skiprows/nrows Parameter
# skiprows will skip the mentioned rows.
# nrows will only fetch the top n number of rows, useful when the dataset is extremely big.

pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/aug_train.csv',skiprows=100) #skips top 100 rows
# Out:
#         8695   city_11   0.55    Male  Has relevent experience  no_enrollment  \
# 0       6172   city_11  0.550    Male  Has relevent experience  no_enrollment
# 1      14672  city_173  0.878     NaN   No relevent experience  no_enrollment
# 2      18257  city_103  0.920  Female  Has relevent experience  no_enrollment
# 3      24493  city_103  0.920     NaN  Has relevent experience  no_enrollment
# 4       1180   city_16  0.910    Male  Has relevent experience  no_enrollment
# ...      ...       ...    ...     ...                      ...            ...
# 19053   7386  city_173  0.878    Male   No relevent experience  no_enrollment
# 19054  31398  city_103  0.920    Male  Has relevent experience  no_enrollment
# 19055  24576  city_103  0.920    Male  Has relevent experience  no_enrollment
# 19056   5756   city_65  0.802    Male  Has relevent experience  no_enrollment
# 19057  23834   city_67  0.855     NaN   No relevent experience  no_enrollment
#
# ...

# %%
#nrows
pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/aug_train.csv',nrows=100) #keeps top 100 rows only
pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/aug_train.csv',nrows=100)
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %%
# Encoding parameter - most of the datasets have utf-8 encoding, but if there is a different encoding then this error pops up.
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 7044: invalid continuation byte

# How to fix this, if you know the encoding then use the encoding parameter, else use any editor to change the encoding for example sublime text.

pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/zomato.csv',encoding='latin-1')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
# dypes parameter - we can override the default datatypes of a column to something more efficient.
# For example here the target was set to float64 but all the values are either 0 or 1, so we can set this to int8

pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/aug_train.csv',dtype={'target':np.int8})

# use np.int32, if you wanna keep default then simply go with 'target':int
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
# Handling Dates

pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/IPL Matches 2008-2020.csv',parse_dates=['date'])

# By default dates are stored as object/str.
# If the day month or year are not given in a single column but as multiple columns then they can be parsed as a single date column -> ref: documentation.
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
# na_values parameter

# If null values are present in dataset as NaN, it's easy to work with them, but what if values are listed as '-' just a hyphen or similer characters 
# now this is hard to work with so we can define while loading the dataset that what values should be considered as NaN.

pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/aug_train.csv',na_values=['Male'])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
# Loading a very huge dataset in chunks.

dfs = pd.read_csv('/Users/utkarshchouhan/Desktop/Python-Libraries/Datasets/datasets-data_analysis_process/aug_train.csv',chunksize=5000)

# dfs = dataframes

# %%
# now to access the chunks we need to access it through for loops.

for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)

# %% [markdown]
# ### Working with Excel Files
